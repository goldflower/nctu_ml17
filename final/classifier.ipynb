# %%
import pandas as pd
import numpy as np
import keras
np.random.seed(0)
from keras.preprocessing.image import ImageDataGenerator

# %%
# CNN
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Dropout
from keras.models import Model
from keras import backend as K
from keras.utils import np_utils

img_size = 96
classes = 8
input_img = Input(shape=(img_size, img_size, 1))

x = Conv2D(3, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Flatten()(x)
x = Dense(1024, activation='relu', kernel_initializer='truncated_normal')(x)
output = Dense(classes, activation='sigmoid', kernel_initializer='truncated_normal')(x)

model = Model(input_img, output)
model.compile(optimizer='Nadam', loss='binary_crossentropy')

# %%
# CNN
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Dropout
from keras.models import Model
from keras import backend as K
from keras.utils import np_utils

img_size = 64
classes = 8
input_img = Input(shape=(img_size, img_size, 1))

x = Conv2D(3, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal', kernel_regularizer='l2')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal', kernel_regularizer='l2')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Dropout(0.5)(x)
x = Flatten()(x)
x = Dense(128, activation='relu', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
output = Dense(classes, activation='sigmoid', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)

model = Model(input_img, output)
model.compile(optimizer='Nadam', loss='binary_crossentropy')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 64, 64, 16)        160
# _________________________________________________________________
# max_pooling2d_67 (MaxPooling (None, 32, 32, 16)        0
# _________________________________________________________________
# dropout_67 (Dropout)         (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 32, 32, 16)        2320
# _________________________________________________________________
# max_pooling2d_68 (MaxPooling (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_68 (Dropout)         (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 16, 16, 16)        2320
# _________________________________________________________________
# max_pooling2d_69 (MaxPooling (None, 8, 8, 16)          0
# _________________________________________________________________
# dropout_69 (Dropout)         (None, 8, 8, 16)          0
# _________________________________________________________________
# conv2d_71 (Conv2D)           (None, 8, 8, 16)          2320
# _________________________________________________________________
# max_pooling2d_70 (MaxPooling (None, 4, 4, 16)          0
# _________________________________________________________________
# dropout_70 (Dropout)         (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_72 (Conv2D)           (None, 4, 4, 16)          2320
# _________________________________________________________________
# max_pooling2d_71 (MaxPooling (None, 2, 2, 16)          0
# _________________________________________________________________
# dropout_71 (Dropout)         (None, 2, 2, 16)          0
# _________________________________________________________________
# conv2d_73 (Conv2D)           (None, 2, 2, 16)          2320
# _________________________________________________________________
# max_pooling2d_72 (MaxPooling (None, 1, 1, 16)          0
# _________________________________________________________________
# dropout_72 (Dropout)         (None, 1, 1, 16)          0
# _________________________________________________________________
# conv2d_74 (Conv2D)           (None, 1, 1, 16)          2320
# _________________________________________________________________
# max_pooling2d_73 (MaxPooling (None, 1, 1, 16)          0
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 1, 1, 16)          0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 16)                0
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               2176
# _________________________________________________________________
# dense_22 (Dense)             (None, 8)                 1032
# =================================================================
# Total params: 17,288.0
# Trainable params: 17,288.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
df = pd.DataFrame(np.load('training_grey_reserve_64.npy'))
test = df.sample(frac=0.1)
train = df.drop(test.index)
train_X = train[train.columns[:-1]].values.astype('float32')/255
train_X = np.reshape(train_X, (len(train_X), img_size, img_size, 1))
train_t = np_utils.to_categorical(train[train.columns[-1]].values)
test_X = test[test.columns[:-1]].values.astype('float32')/255
test_X = np.reshape(test_X, (len(test_X), img_size, img_size, 1))
test_t = test[test.columns[-1]].values
test_t = np_utils.to_categorical(test_t)

# %%
count = {}
for line in train_t:
    count[np.argmax(line)] = count.get(np.argmax(line), 0) + 1
total = np.sum(list(count.values()))
for key in count.keys():
    count[key] = 1/count[key]*total

# %%
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)
datagen.fit(train_X)

# %%
# history = model.fit_generator(datagen.flow(train_X, train_t, batch_size=32),
#                               steps_per_epoch=len(train_X)//32, epochs=100,
#                               validation_data=(test_X, test_t), class_weight=count)
history = model.fit(train_X, train_t, batch_size=32, epochs=150, shuffle=True,
                    validation_data=(test_X, test_t), class_weight=count)
# Out:
# Train on 6646 samples, validate on 738 samples
# Epoch 1/150
# 6646/6646 [==============================] - 22s - loss: 3.4174 - val_loss: 0.4502
# Epoch 2/150
# 6646/6646 [==============================] - 21s - loss: 3.0798 - val_loss: 0.4163
# Epoch 3/150
#  - ETA: 18s - loss: 3.0842
# Epoch 4/150
#  - ETA: 18s - loss: 3.0440
# Epoch 5/150
#  - ETA: 8s - loss: 3.0396
# Epoch 6/150
# 6646/6646 [==============================] - 22s - loss: 3.0366 - val_loss: 0.3895
# Epoch 7/150
# 6646/6646 [==============================] - 22s - loss: 3.0355 - val_loss: 0.3926
# Epoch 8/150
#  - ETA: 12s - loss: 3.0535
# Epoch 9/150
# 6646/6646 [==============================] - 23s - loss: 3.0329 - val_loss: 0.3875
# Epoch 10/150
# 6646/6646 [==============================] - 21s - loss: 3.0326 - val_loss: 0.3917
# Epoch 11/150
# 6646/6646 [==============================] - 22s - loss: 3.0319 - val_loss: 0.3888
# Epoch 12/150
# 2112/6646 [========>.....................] - ETA: 15s - loss: 3.0242
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-87-93c80e8d499d> in <module>()
#       3 #                               validation_data=(test_X, test_t), class_weight=count)
#       4 history = model.fit(train_X, train_t, batch_size=32, epochs=150, shuffle=True,
# ----> 5                     validation_data=(test_X, test_t), class_weight=count)
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1483                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1484                               callback_metrics=callback_metrics,
# -> 1485                               initial_epoch=initial_epoch)
#    1486
#    1487     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1138                 batch_logs['size'] = len(batch_ids)
#    1139                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1140                 outs = f(ins_batch)
#    1141                 if not isinstance(outs, list):
#    1142                     outs = [outs]
#
# /usr/local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2073         session = get_session()
#    2074         updated = session.run(self.outputs + [self.updates_op],
# -> 2075                               feed_dict=feed_dict)
#    2076         return updated[:len(self.outputs)]
#    2077
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
history = model.fit(train_X, train_t, batch_size=32, epochs=200, shuffle=True, initial_epoch=200,
                    validation_data=(test_X, test_t), class_weight=count)

# %%
predict = model.predict(train_X)
result = np.argmax(predict, axis=1) == np.argmax(train_t, axis=1)
len(result[result==True]) / len(result)
# Out:
# 0.13496840204634367

# %%
predict = model.predict(test_X)
result = np.argmax(predict, axis=1) == np.argmax(test_t, axis=1)
len(result[result==True]) / len(result)
# Out:
# 0.12737127371273713
