# %%
import pandas as pd
import numpy as np
import keras
np.random.seed(0)
import os

# %% [markdown]
# ## Model 在keras中的意義
#
# keras中, 建立整個計算圖(目前)分為sequential和model兩種, model類似於以往的graph, 在sequential中, 層間只有相鄰的關係, 跨層就沒有關係, 而model則是廣義的, 愛怎麼連就怎麼連, 只要inputs和outputs都是一個或一群tensor就可以。

# %%
m = np.load('training_grey.npy')

# %%
m.shape
# Out:
# (5452, 33490)

# %%
# convolution autoencoder
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras import backend as K

img_size = 128
input_img = Input(shape=(img_size, img_size, 1))

x = Conv2D(128, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='Nadam', loss='binary_crossentropy')

# %%
# for convolution
df = pd.DataFrame(np.load('training_grey_128.npy'))
test = df.sample(frac=0.1)
train = df.drop(test.index)
train_X = train[train.columns[:-1]].values.astype('float32')/255
train_X = np.reshape(train_X, (len(train_X), img_size, img_size, 1))
train_t = train[train.columns[-1]].values
test_X = test[test.columns[:-1]].values.astype('float32')/255
test_X = np.reshape(test_X, (len(test_X), img_size, img_size, 1))
test_t = test[test.columns[-1]].values
# 並不直接去train encoder/decoder, 而是train autoencoder, 把其中的結果拿出來作為encoder/decoder
history = autoencoder.fit(train_X, train_X, epochs=100, batch_size=16,
                          shuffle=True, validation_data=(test_X, test_X))
# Out:
# Train on 4907 samples, validate on 545 samples
# Epoch 1/100
#   16/4907 [..............................] - ETA: 1413s - loss: 0.6947
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-48ac7e98b03d> in <module>()
#      11 # 並不直接去train encoder/decoder, 而是train autoencoder, 把其中的結果拿出來作為encoder/decoder
#      12 history = autoencoder.fit(train_X, train_X, epochs=100, batch_size=16,
# ---> 13                           shuffle=True, validation_data=(test_X, test_X))
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1483                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1484                               callback_metrics=callback_metrics,
# ...

# %%
# autoencoder
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras import backend as K

img_size = 183
input_img = Input(shape=(img_size**2,))

x = Dense(512, activation='relu', kernel_initializer='truncated_normal')(input_img)
x = Dense(256, activation='relu', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = Dense(128, activation='relu', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = Dense(64, activation='relu', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = Dense(32, activation='relu', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
encoded = Dense(16, activation='relu', kernel_initializer='truncated_normal')(input_img)

x = Dense(32, activation='relu', kernel_initializer='truncated_normal')(encoded)
x = Dense(64, activation='relu', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = Dense(128, activation='relu', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = Dense(256, activation='relu', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
x = Dense(512, activation='relu', kernel_initializer='truncated_normal', kernel_regularizer='l2')(x)
decoded = Dense(img_size**2, activation='sigmoid', kernel_initializer='truncated_normal')(encoded)

encoder = Model(input_img, encoded)
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_5 (InputLayer)         (None, 33489)             0
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                535840
# _________________________________________________________________
# dense_25 (Dense)             (None, 33489)             569313
# ...
# Total params: 1,105,153.0
# Trainable params: 1,105,153.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
# for normal
df = pd.DataFrame(np.load('training_grey_64.npy'))
test = df.sample(frac=0.1)
train = df.drop(test.index)
train_X = train[train.columns[:-1]].values.astype('float32')/255
train_t = train[train.columns[-1]].values
test_X = test[test.columns[:-1]].values.astype('float32')/255
test_t = test[test.columns[-1]].values
# 並不直接去train encoder/decoder, 而是train autoencoder, 把其中的結果拿出來作為encoder/decoder
# history = autoencoder.fit(train_X, train_X, epochs=500, batch_size=16,
#                           shuffle=True, validation_data=(test_X, test_X))

# %%
# MSE/Adam/NAdam在結果上差不多
import matplotlib.pyplot as plt
# list all data in history
print(history.history.keys())
# summarize history for accuracy
# line1, = plt.plot(np.log(history.history['loss']))
# line2, = plt.plot(np.log(history.history['val_loss']))
line1, = plt.plot(history.history['loss'])
line2, = plt.plot(history.history['val_loss'])
plt.legend((line1, line2), ('training loss', 'validation loss'), loc='best')
plt.show()
plt.close()
# Out:
# dict_keys(['val_loss', 'loss'])

# %%
# encoder.save('encoder_32')
# autoencoder.save('autoencoder_32')
encoder = keras.models.load_model('conv_encoder_resolve_128')
autoencoder = keras.models.load_model('conv_autoencoder_resolve_128')
# Out:
# /usr/local/lib/python3.6/site-packages/keras/models.py:240: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
# encode and decode some digits
#encoder = Model(input_img, encoded)
encoded_imgs = encoder.predict(test_X)
decoded_imgs = autoencoder.predict(test_X)
#畫一些圖看一下效果
import matplotlib.pyplot as plt
size = 64
n = 10  # how many digits we will display
plt.figure(figsize=(100, 10))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(test_X[i].reshape(size, size))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(size, size))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.savefig('results.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b8a8637b5656> in <module>()
#       1 # encode and decode some digits
#       2 #encoder = Model(input_img, encoded)
# ----> 3 encoded_imgs = encoder.predict(test_X)
#       4 decoded_imgs = autoencoder.predict(test_X)
#       5 #畫一些圖看一下效果
#
# NameError: name 'test_X' is not defined

# %% [markdown]
# ### X = pd.DataFrame(encoder.predict(train_X))
# X.to_csv('X_train_encoded.csv', header=False, index=False)
# X_test = pd.DataFrame(encoder.predict(test_X))
# X_test.to_csv('X_test_encoded.csv', header=False, index=False)

# %%
# non reserve
import pandas as pd
import numpy as np
import keras
img_size = 64
df = pd.DataFrame(np.load('training_grey_{}.npy'.format(img_size)))
test = df.sample(frac=0.1)
train = df.drop(test.index)
train_X = train[train.columns[:-1]].values.astype('float32')/255
train_t = train[train.columns[-1]].values
test_X = test[test.columns[:-1]].values.astype('float32')/255
test_t = test[test.columns[-1]].values
# 並不直接去train encoder/decoder, 而是train autoencoder, 把其中的結果拿出來作為encoder/decoder
# history = autoencoder.fit(train_X, train_X, epochs=500, batch_size=16,
#                           shuffle=True, validation_data=(test_X, test_X))

# encoder.save('encoder_32')
# autoencoder.save('autoencoder_32')
encoder = keras.models.load_model('conv_encoder_resolve_128')
autoencoder = keras.models.load_model('conv_autoencoder_resolve_128')

# encode and decode some digits
#encoder = Model(input_img, encoded)
encoded_imgs = encoder.predict(test_X)
decoded_imgs = autoencoder.predict(test_X)
#畫一些圖看一下效果
import matplotlib.pyplot as plt
n = 10  # how many digits we will display
plt.figure(figsize=(100, 10))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(test_X[i].reshape(img_size, img_size))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(img_size, img_size))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.savefig('results.png')
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/keras/models.py:240: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-e586967f221d> in <module>()
#      22 # encode and decode some digits
#      23 #encoder = Model(input_img, encoded)
# ---> 24 encoded_imgs = encoder.predict(test_X)
#      25 decoded_imgs = autoencoder.predict(test_X)
#      26 #畫一些圖看一下效果
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose)
#    1552         x = _standardize_input_data(x, self._feed_input_names,
#    1553                                     self._feed_input_shapes,
# -> 1554                                     check_batch_axis=False)
# ...

# %%
# reserve
import pandas as pd
import numpy as np
import keras
img_size = 128
train = pd.DataFrame(np.load('training_grey_rescale_128.npy'))
train_X = train[train.columns[:-1]].values.astype('float32')/255
train_t = train[train.columns[-1]].values
test = pd.DataFrame(np.load('testing_grey_rescale_128.npy'))
test_X = test[test.columns[:-1]].values.astype('float32')/255
test_t = test[test.columns[-1]].values
# 並不直接去train encoder/decoder, 而是train autoencoder, 把其中的結果拿出來作為encoder/decoder
# history = autoencoder.fit(train_X, train_X, epochs=500, batch_size=16,
#                           shuffle=True, validation_data=(test_X, test_X))

# encoder.save('encoder_32')
# autoencoder.save('autoencoder_32')
encoder = keras.models.load_model('conv_encoder_resolve_128')
autoencoder = keras.models.load_model('conv_autoencoder_resolve_128')

# encode and decode some digits
#encoder = Model(input_img, encoded)
encoded_imgs = encoder.predict(test_X.reshape((len(test_X), img_size, img_size, 1)))
decoded_imgs = autoencoder.predict(test_X.reshape((len(test_X), img_size, img_size, 1)))
#畫一些圖看一下效果
import matplotlib.pyplot as plt
n = 10  # how many digits we will display
plt.figure(figsize=(100, 10))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(test_X[i].reshape(img_size, img_size))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(img_size, img_size))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.savefig('results.png')
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/keras/models.py:240: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
np.save('training_resolve_128', encoder.predict(train_X.reshape((len(train_X), img_size, img_size, 1))))
np.save('testing_resolve_128', encoder.predict(test_X.reshape((len(test_X), img_size, img_size, 1))))

# %%
import scipy.misc as misc
import numpy as np
path = '2/all/'
imgs = []
for i in range(640):
    img = misc.imread(path + str(i) + '.jpg', mode='L').flatten()
imgs = np.array(imgs)
df = pd.DataFrame(imgs)
# Out:
# 1.jpg
