# %%
import random
import sys
import numpy as np
from scipy.special import expit
from scipy import misc, stats

import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
import os

from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn import svm

# %%
img_width = 30
img_height = 30
file_path = 'Data_Train'
class_names = ['Class1', 'Class2', 'Class3']
int_to_class = {0:'Class1', 1:'Class2', 2:'Class3'}

# %%
def get_data(img_width = 30, img_height = 30,
             file_path = 'Data_Train', class_names = None,
             validation_ratio = 0.2, nb_samples = [1000,1000,1000],
             data_augmentation=False):
    """ get training/validation data
    
        data structure:
            training_data (list): 
                training_data = [sample data points]
                sample data points = (input data point, target of input data point)
    """
    if class_names is None: # testing, no answer
        img_path = [str(a)+'.bmp' for a in range(1, len(os.listdir(file_path))+1)]
        #print(img_path)
        df = pd.DataFrame(index = range(len(img_path)), columns = range(img_height*img_width))
        for file, i in zip(img_path, range(0, len(img_path))):
            img = misc.imread(file_path + '/' + file).flatten()
            df.iloc[i] = img
        return df
        
    train_df = pd.DataFrame(columns = range(img_height*img_width))
    train_df['class'] = 0
    augmentation_df = pd.DataFrame(columns = range(img_height*img_width))
    augmentation_df['class'] = 0
    for i in range(len(class_names)):
        path = file_path + '/' + class_names[i] + '/'
        print(path)
        class_img_files = os.listdir(path)[:nb_samples[i]]
        
        df = pd.DataFrame(index = range(len(class_img_files)), columns = range(img_height*img_width))
        aug_df = pd.DataFrame(columns = range(img_height*img_width))
        for file, j in zip(class_img_files, range(len(class_img_files))):
            img_path = path + file
            img = misc.imread(img_path).flatten()
            df.iloc[j] = img
            if data_augmentation:
                img = img.reshape((img_height, img_width))
                # rotate
                angle = [random.randint(10, 20), random.randint(-20, -10)][random.randint(0,1)]
                img1 = misc.imrotate(img, angle)
                img1 = img1.flatten()        
                aug_df = aug_df.append(pd.Series(img1), ignore_index=True)
                # flip
                img2 = np.fliplr(img)
                img2 = img2.flatten()
                aug_df = aug_df.append(pd.Series(img2), ignore_index=True)
        df['class'] = class_names[i]
        aug_df['class'] = class_names[i]
        train_df = train_df.append(df)
        augmentation_df = augmentation_df.append(aug_df)
        
    np.random.seed(0)
    train_df = train_df.sample(frac=1)
    train_df, val_df = train_df.iloc[:int(len(train_df)*(1-validation_ratio))], train_df.iloc[int(len(train_df)*(1-validation_ratio)):]
    train_df = train_df.append(augmentation_df)
    
    train_class = train_df['class']
    train_class.index = range(len(train_class))
    train_df = train_df.drop('class', axis=1)
    train_df.index = range(len(train_df))
    val_class = val_df['class']
    val_class.index = range(len(val_class))
    val_df = val_df.drop('class', axis=1)
    val_df.index = range(len(val_df))
    
    return train_df, train_class, val_df, val_class

# %%
def show_importance_graph(pcas, name=None):
    """ draw the explained variance ratio
    """
    for p, j in zip(pcas, range(1, len(pcas)+1)):
        var_exp = [i for i in sorted(np.abs(p.explained_variance_ratio_), reverse=True)]
        cum_var_exp = np.cumsum(var_exp)
        print(str(j)+'_top_10 cumsum:', cum_var_exp[:10])
#         plt.bar(range(1, len(var_exp)+1), var_exp, alpha=0.5, align='center',
#                 label=str(j)+'_Individual')
        plt.step(range(1, len(var_exp)+1), cum_var_exp, where='mid',
                 label=str(j)+'_Cumulative')
    plt.title('Cumulative Importance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()
    if name is None:
        plt.savefig('fig-pca-var-exp.png', dpi=300)
    else:
        plt.savefig(name, dpi=300)
    plt.show()

# %%
def pca_transform(train_df, test_data):
    pca = PCA(n_components=2).fit(scale(train_df))
    testing = pca.fit_transform(scale(test_data))
    return testing

# %%
def preprocessing(train_df, train_class, val_df, val_class, class_names = None, pca=True):
    """ 1. PCA 2. mapping string name to integer and vise versa
    """
    class_to_one_hot = {}
    int_to_class = {}
    for i, j in zip(np.sort(class_names), range(len(class_names))):
        one_hot = np.zeros((len(class_names), 1))
        one_hot[j] = 1
        class_to_one_hot[i] = one_hot
        int_to_class[j] = i
    if pca:
        pca = PCA(n_components=2).fit(scale(train_df))
        pca_train = pca.fit_transform(scale(train_df))
        pca_val = pca.fit_transform(scale(val_df))
        train_inputs = [np.ndarray.astype(row.reshape((2, 1)), np.float64) for row in pca_train]
        val_inputs = [np.ndarray.astype(row.reshape((2, 1)), np.float64) for row in pca_val]
    else:
        train_inputs = [np.ndarray.astype(row.reshape((900, 1)), np.float64) for row in train_df.values]
        val_inputs = [np.ndarray.astype(row.reshape((900, 1)), np.float64) for row in val_df.values]        
    train_results = [class_to_one_hot[i] for i in train_class]
    training_data = zip(train_inputs, train_results)
    
    val_results = [class_to_one_hot[i] for i in val_class]
    validation_data = zip(val_inputs, val_results)
    return list(training_data), list(validation_data), int_to_class

# %%
train_df, train_class, val_df, val_class = get_data(file_path=file_path, class_names=class_names, 
                                                    nb_samples=[1000,1000,1000], data_augmentation=False)
pca1 = PCA().fit(train_df)
train_df, train_class, val_df, val_class = get_data(file_path=file_path, class_names=class_names, 
                                                    nb_samples=[1000,1000,1000], data_augmentation=True)
pca2 = PCA().fit(train_df)
show_importance_graph([pca1, pca2])
# Out:
# Data_Train/Class1/
# Data_Train/Class2/
# Data_Train/Class3/
# Data_Train/Class1/
# Data_Train/Class2/
# Data_Train/Class3/
# 1_top_10 cumsum: [ 0.24218724  0.34330065  0.42619605  0.48624441  0.52811904  0.56329079
#   0.59450494  0.61902559  0.64244073  0.66301486]
# 2_top_10 cumsum: [ 0.20802166  0.29558112  0.37402674  0.45161599  0.50077187  0.53080073
#   0.5582675   0.58382044  0.60788964  0.62990701]

# %%
train_df, train_class, val_df, val_class = get_data(file_path=file_path, class_names=class_names, 
                                                    nb_samples=[1000,1000,1000], data_augmentation=True)
training, validation, int_to_class = preprocessing(train_df, train_class, val_df, val_class, class_names=class_names, pca=True)
# Out:
# Data_Train/Class1/
# Data_Train/Class2/
# Data_Train/Class3/

# %%
class NeuronNetwork():
    
    def __init__(self, auto=True):
        """Initialize NN
        
        Args:
            auto (bool): True: you don't have to create output layer
                               we'll add it automatically
                         False: the last layer you added is your output layer # not tested
        
        Returns:
            None
        """
        np.random.seed(0) # for same result
        self.num_layers = 1 # set input layer as layer 0
        self.fitted = False # fit any data yet?
        self.weights = {} # record weights of each layer
        self.biases = {} # record biases of each layer
        self.num_neurons = {} # record number of neurons of each layer
        self.auto = auto # you know it
        self.activation_functions = {'sigmoid':self.sigmoid, 'relu':self.relu, 'tanh':self.tanh, 'leaky_relu':self.leaky_relu} # for clean
        self.f = None # alias of activeation function (bad idea)
        self.seesee = {} # for debug
        self.MAX = None # prevent overflow of sigmoid

    def add_layer(self, num_neurons, initialization='normal', input_size=None):
        """Add layers into NN
        
        Args:
            num_neurons (int): number of neurons of this layer
            initialization (str): 1. normal: normal distribution, zero mean and unit variance
                                  2. scaled_normal: result of 1. multiply sqrt(1/n), n is number of data
                                  3. uniform_random: uniform random from 0 to 1
                                  4. scaled_normal_relu: result of 1. multiply sqrt(2/n), n is number of data
            input_size (int): only used at first layer, need to specify the size
        Returns:
            None
        """
        np.random.seed(0)
        if self.num_layers == 1: # layer 1, don't know input structure yet
            if input_size == None:
                print('in first layer, you need to specity the input size.')
                return
            self.num_neurons[self.num_layers] = num_neurons
            if initialization == 'normal': # bad
                self.weights[self.num_layers] = np.random.normal(scale=1, 
                                                   size=(num_neurons, input_size))
            elif initialization == 'scaled_normal_relu': # best
                self.weights[self.num_layers] = (np.random.normal(scale=1, 
                                                    size=(num_neurons, input_size))
                                                   *np.sqrt(2/self.num_neurons[1]))
            elif initialization == 'scaled_normal': # good
                self.weights[self.num_layers] = (np.random.normal(scale=1, 
                                                    size=(num_neurons, input_size))
                                                   /np.sqrt(self.num_neurons[1]))                
            elif initialization == 'uniform_random': # soso
                self.weights[self.num_layers] = np.random.random(size=(num_neurons, input_size))
            
            self.biases[self.num_layers] = np.zeros(shape=(num_neurons,1))
            print('add layer ', self.num_layers)
            self.num_layers += 1
            
        else:
            if initialization == 'normal':
                self.weights[self.num_layers] = np.random.normal(scale=1, 
                                                                 size=(num_neurons, self.num_neurons[self.num_layers-1]))
            elif initialization == 'scaled_normal_relu':
                self.weights[self.num_layers] = (np.random.normal(scale=1, 
                                                    size=(num_neurons, self.num_neurons[self.num_layers-1]))
                                                   *np.sqrt(2/self.num_neurons[1])) 
            elif initialization == 'scaled_normal':
                self.weights[self.num_layers] = (np.random.normal(scale=1, 
                                                                  size=(num_neurons, self.num_neurons[self.num_layers-1]))
                                                   /self.num_neurons[1])                
            elif initialization == 'uniform_random':
                self.weights[self.num_layers] = np.random.random(size=(num_neurons, self.num_neurons[self.num_layers-1]))
            self.biases[self.num_layers] = np.zeros(shape=(num_neurons, 1))
            self.num_neurons[self.num_layers] = num_neurons
            print('add layer ', self.num_layers)
            self.num_layers += 1
            

    def tanh(self, x, derivative=False):
        pass

    def sigmoid(self, x, derivative=False):
        if not derivative:
            return np.exp(-np.logaddexp(0, -x))
        else:
            return (1-self.sigmoid(x))*self.sigmoid(x)

    def softmax(self, x):
        MAX = np.max(x)
        results = np.exp(x-MAX) / np.sum(np.exp(x-MAX), axis=0)
        #print(MAX, results)
        return results
    
    def relu(self, x, derivative=False):
        result = []
        if not derivative:
            #return np.array([0 if a < 0 else a for a in x]).reshape(-1,1)
            return x*(x>0)
        else:
            #return np.array([0 if a < 0 else 1 for a in x]).reshape(-1,1)
            return 1*(x > 0).reshape(-1,1)
                    
    def leaky_relu(self, x, derivative=False, alpha=0.01):
        if not derivative:
            results = np.array([alpha*a if a < 0 else a for a in x]).reshape(-1,1)
            #print(results)
            return results
        else:
            results = np.array([alpha if a <= 0 else 1 for a in x]).reshape(-1,1)
            return results
        
    def predict(self, x):
        """the prediction of given data
        we don't need softmax to inference
        
        Args:
            x (numpy.ndarray): the data point
        Returns:
            the result of prediction
        """
        if not self.fitted:
            print('not fitted')
            return
        # if we have 3 weights, they are w_1, w_2, w_3
        # which means we have 3-layers (exclude input layer)
        a = x.reshape(len(x), 1)
        ##print('input: \n', a)
        for i in range(1, self.num_layers+1):
            W = self.weights[i]
            #print('w: \n ', W)
            b = self.biases[i]
            #print('b: \n', b)
            z = np.dot(W,a) + b
            #print('z: \n', z)
            a = self.f(z)
            #print('a: \n', a)
        return a
    
    def fit(self, training_data, batch_size=64, epochs=10, activation_function='leaky_relu', 
            learning_rate=0.001, decreasing_rate=0.9, test_data=None, verbose=False,
            dropout=None, l2 = None, update_method='SGD', mu=None, v=True): 
        """Fit the data
        
        Args:
            training_data (list): 
                training_data = [sample data points]
                sample data points = (input data point, target of input data point)
            batch_size (int): batch size
            epochs (int): epoch
            activation_function (string): 1. relu
                                          2. sigmoid
                                          3. tanh # not implemented
            learning_rate (float): learning rate
            decreasing_rate (float): after one epoch, learning = learning*decreasing_rate
            test_data (numpy.ndarray): for evaluation
            verbose (bool): for more infomation when training
            dropout (float): the rate of dropout, this value is between 0 and 1 # not implemented
            l2 (float): l2 regularization # not implemented
            update_method (string): 1. SGD, stochastic gradient descent
                                    2. momentum # not implemented
                                    3. Adagrad # not implemented
                                    4. RMSprop # not implemented
                                    5. Adam # not implemented
            mu (float): for all momentum-like update methods
            v (bool): for momentum-like methods
        Returns:
            None
        """
        
        self.MAX = max([np.max(data[0]) for data in training]) # prevent overflow of sigmoid
        np.random.seed(0)
        next_mu = mu
        if mu is not None:
            friction_range = 0.99-mu # bad coding style :( 
        self.f = self.activation_functions[activation_function]
        if self.auto and not self.fitted:
            print("did not specify the output layer, but set 'auto', automatically added output layer based on the shape of the target.")
            self.add_layer(training_data[0][1].shape[0])
            self.num_layers -= 1
        self.fitted = True
        print('start training!')
        for i in range(epochs):
            #print(self.weights[2])
            
            np.random.shuffle(training_data) # shuffle the data
            batchs = [training_data[k:k+batch_size] for k in range(0,len(training_data),batch_size)] # create batches
            for batch, j in zip(batchs, range(len(batchs))):
                if verbose and j % 20 == 0:
                    print('batch {} / {}'.format(i, len(batchs)))
                self.update(batch, learning_rate, mu=next_mu, v=v)
            
            if test_data is not None:
                train_evl = self.evaluate(training_data)
                val_evl = self.evaluate(test_data)
                print('Epoch {}, training accuracy: {} / {} ({}%); validation accuracy: {} / {} ({}%)'.format(i, train_evl, len(training_data), str(100*train_evl/len(training_data))[:5], 
                                                                                                              val_evl, len(test_data), str(100*val_evl/len(test_data))[:5]))
            else:
                print('Epoch {} complete'.format(i))
            if mu is not None:
                next_mu = mu + friction_range * (i/epochs)
            else:
                learning_rate *= decreasing_rate
                #print(learning_rate)

    def feedforward(self, x):   
        """feedforward pass
        
        Args:
            x (numpy.ndarray): the data points
        Returns:
            zs (dict): the inputs of each layer
            activations (dict): the outputs of each layer
        """
        activations = {0:x}
        activation = activations[0]
        zs = {}
        for i in range(1, self.num_layers+1):
            w = self.weights[i]
            b = self.biases[i]
            z = np.dot(w, activation) + b
            #print(z)
            zs[i] = z
            if i == self.num_layers: # output layer, use softmax
                activation = self.softmax(z)
                #print(np.sum(activation))
            else:
                activation = self.f(z)
            self.seesee[i] = activation
            activations[i] = activation
        return zs, activations
    
    def backpropagation(self, y, zs, activations):
        """backward pass
        
        Args:
            y (numpy.ndarray): the target of each data points
            zs (dict): the inputs of each layer
            activations (dict): the outputs of each layer
        Returns:
            weight_gradients (dict): dC/dw of each layer
            bias_gradients (dict): dC/db of each layer
        """
        bias_gradients = {}
        weight_gradients = {}
        deltas = {}
        delta = None                                 
        deltas[self.num_layers-1] = 0
        # compute delta(error) of each layer
        for i in range(self.num_layers, 0, -1):
            z = zs[i]
            activation = activations[i]

            if i == self.num_layers: # output layer
                delta = activation - y
                deltas[i] = delta
            else:
                da_dz = self.f(z, derivative=True)
                delta = deltas[i+1] # delta l+1
                delta = np.dot(self.weights[i+1].T, delta) * da_dz # delta l
                deltas[i] = delta
        #print(zs)
        #print(deltas)
        # compute delta_(l) * a_(l-1).T
        for i in range(self.num_layers, 0, -1):
            weight_gradients[i] = np.dot(deltas[i], activations[i-1].T)
            bias_gradients[i] = deltas[i]
        #print(weight_gradients)
        return weight_gradients, bias_gradients
            
    def update(self, batch_data, learning_rate, mu, v):
        """update by mini batch
        
        Args:
            batch_data (numpy.ndarray): the batch data points
            learning_rate (float): learning rate
            v (float) for momentum-like methods
        Returns:
            None
        """
        weight_adjustments = {}
        bias_adjustments = {}
        for x, y in batch_data:
            # dC/dw and dC/db of each layer
            zs, activations = self.feedforward(x)
            weight_gradients, bias_gradients = self.backpropagation(y, zs, activations)
            
            # one batch update once, sum up all gradients first
            for i in range(1, self.num_layers+1):
                weight_adjustments[i] = weight_adjustments.get(i, np.zeros(shape=weight_gradients[i].shape)) + weight_gradients[i]
                bias_adjustments[i] = bias_adjustments.get(i, np.zeros(shape=bias_gradients[i].shape)) + bias_gradients[i]
        self.adjust = weight_adjustments
        # update with mean of gradients
        for i in range(self.num_layers, 0, -1):
            #print(len(batch_data))
            dC_dw = weight_adjustments[i]/len(batch_data)
            dC_db = bias_adjustments[i]/len(batch_data)
            if mu is None:
                self.weights[i] -= learning_rate*dC_dw
                self.biases[i] -= learning_rate*dC_db
            else: # vanilla momentum
                v[0] = mu*v[0] - learning_rate*dC_dw
                v[1] = mu*v[1] - learning_rate*dC_db
                self.weights[i] += v[0]
                self.biases[i] += v[1]
                
    def evaluate(self, test_data):
        """evaluate model
        
        Args:
            test_data (numpy.ndarray): test data
        Returns:
            the correct predicted number
        """
        #print(type(test_data[0][1]))
        if isinstance(test_data[1], np.ndarray):
            #print(1)
            results = [(np.argmax(self.predict(x)), y) for (x, y) in test_data]
        else:
            #print(2)
            results = [(np.argmax(self.predict(x)), np.argmax(y)) for (x, y) in test_data]
        return sum(int(x == y) for (x, y) in results)
    
    def draw_boundary(training_data, predict_function, int_to_class, val_X=None, val_y=None,
                      title=None):

        X = np.array([training_data[i][0][0] for i in range(len(training_data))])
        Y = np.array([training_data[i][0][1] for i in range(len(training_data))])
        target = np.array([np.argmax(training_data[i][1]) for i in range(len(training_data))])
        x_min, x_max = np.min(X), np.max(X)
        y_min, y_max = np.min(Y), np.max(Y)
        # the position and size of window
        x_min -= 0.1*abs(x_max - x_min)
        x_max += 0.1*abs(x_max - x_min)
        y_min -= 0.1*abs(y_max - y_min)
        y_max += 0.1*abs(y_max - y_min)
        r = abs(abs(x_max) - abs(x_min)) / 500
        xx, yy = np.meshgrid(np.arange(x_min, x_max, max(0.2,r)),
                             np.arange(y_min, y_max, max(0.2,r)))
        # here is model's prediction (classification) function
        Z = []
        print('create prediction...')
        for data_point in np.c_[xx.ravel(), yy.ravel()]:
            idx = np.argmax(np.array(predict_function(np.array(data_point).reshape(len(data_point), 1))))
            Z.append(idx)
        z = np.array(Z)
        # put the result into a color plot
        # 1. decision boundary
        Z = z.reshape(xx.shape)
        plt.style.use('seaborn')
        #plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
        #plt.contourf(xx, yy, Z, cmap=plt.cm.CMRmap)
        #plt.contourf(xx, yy, Z, cmap=plt.cm.Accent)
        plt.contourf(xx, yy, Z, cmap=plt.cm.Paired_r)
        #plt.axis('off')

        colors = ['r', 'b', 'g']
        markers = ['s', 'x', 'o'] 

        # 2. data points
        print('plot data points')
        for l, c, m in zip(range(len(int_to_class)), colors, markers):
            tmp_X = X[np.where(target == l)[0]]
            tmp_Y = Y[np.where(target == l)[0]]
            plt.scatter(tmp_X, tmp_Y,
                        c=c, label=int_to_class[l], marker=m)
        plt.title(title)
        plt.xlabel('axis 1')
        plt.ylabel('axis 2')
        plt.legend(loc='best')
        plt.tight_layout()
        plt.savefig(title+'.png', dpi=300)

        plt.show()
        plt.close()

# %%
NN_sigmoid = NeuronNetwork()
NN_sigmoid.add_layer(300, initialization='scaled_normal_relu', input_size=training[0][0].shape[0])
#NN.add_layer(200, initialization='scaled_normal_relu')
#NN.add_layer(50)
NN_sigmoid.fit(training_data=training, epochs=200, activation_function='sigmoid', batch_size=256,
       learning_rate = 0.1, decreasing_rate=0.95, test_data=validation, verbose=False)
# Out:
# add layer  1
# did not specify the output layer, but set 'auto', automatically added output layer based on the shape of the target.
# add layer  2
# start training!
# Epoch 0, training accuracy: 2322 / 2400 (96.75%); validation accuracy: 580 / 600 (96.66%)
# Epoch 1, training accuracy: 2361 / 2400 (98.37%); validation accuracy: 591 / 600 (98.5%)
# Epoch 2, training accuracy: 2364 / 2400 (98.5%); validation accuracy: 591 / 600 (98.5%)
# Epoch 3, training accuracy: 2354 / 2400 (98.08%); validation accuracy: 589 / 600 (98.16%)
# Epoch 4, training accuracy: 2354 / 2400 (98.08%); validation accuracy: 589 / 600 (98.16%)
# Epoch 5, training accuracy: 2362 / 2400 (98.41%); validation accuracy: 589 / 600 (98.16%)
# Epoch 6, training accuracy: 2354 / 2400 (98.08%); validation accuracy: 588 / 600 (98.0%)
# Epoch 7, training accuracy: 2358 / 2400 (98.25%); validation accuracy:
)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6db76cc0a489> in <module>()
#       4 #NN.add_layer(50)
#       5 NN_sigmoid.fit(training_data=training, epochs=200, activation_function='sigmoid', batch_size=256,
# ----> 6        learning_rate = 0.1, decreasing_rate=0.95, test_data=validation, verbose=False)
#
# <ipython-input-8-e083d92f8ea6> in fit(self, training_data, batch_size, epochs, activation_function, learning_rate, decreasing_rate, test_data, verbose, dropout, l2, update_method, mu, v)
#     192                 if verbose and j % 20 == 0:
#     193                     print('batch {} / {}'.format(i, len(batchs)))
# --> 194                 self.update(batch, learning_rate, mu=next_mu, v=v)
#     195
#     196             if test_data is not None:
#
# <ipython-input-8-e083d92f8ea6> in update(self, batch_data, learning_rate, mu, v)
#     292             for i in range(1, self.num_layers+1):
#     293                 weight_adjustments[i] = weight_adjustments.get(i, np.zeros(shape=weight_gradients[i].shape)) + weight_gradients[i]
# --> 294                 bias_adjustments[i] = bias_adjustments.get(i, np.zeros(shape=bias_gradients[i].shape)) + bias_gradients[i]
#     295         self.adjust = weight_adjustments
#     296         # update with mean of gradients
#
# KeyboardInterrupt:

# %%
NN_leaky_relu = NeuronNetwork()
NN_leaky_relu.add_layer(25, initialization='scaled_normal', input_size=training[0][0].shape[0])
NN_leaky_relu.add_layer(25, initialization='scaled_normal')

NN_leaky_relu.fit(training_data=training, epochs=200, activation_function='leaky_relu', batch_size=64,
       learning_rate = 0.05, decreasing_rate=0.95, test_data=validation, verbose=False)
# Out:
# add layer  1
# add layer  2
# did not specify the output layer, but set 'auto', automatically added output layer based on the shape of the target.
# add layer  3
# start training!
# Epoch 0, training accuracy: 7167 / 8400 (85.32%); validation accuracy: 582 / 600 (97.0%)
# Epoch 1, training accuracy: 7047 / 8400 (83.89%); validation accuracy: 573 / 600 (95.5%)
# Epoch 2, training accuracy: 7329 / 8400 (87.25%); validation accuracy: 579 / 600 (96.5%)
# Epoch 3, training accuracy: 7400 / 8400 (88.09%); validation accuracy: 584 / 600 (97.33%)
# Epoch 4, training accuracy: 7342 / 8400 (87.40%); validation accuracy: 545 / 600 (90.83%)
# Epoch 5, training accuracy: 7029 / 8400 (83.67%); validation accuracy: 526 / 600 (87.66%)
# Epoch 6, training accuracy: 7089 / 8400 (84.39%); validation accuracy: 553 / 600 (92.16%)
# Epoch 7, training accuracy: 7231 / 8400 (86.08%); validation accuracy: 529 / 600 (88.16%)
# Epoch 8, training accuracy: 7358 / 8400 (87.59%); validation accuracy: 569 / 600 (94.83%)
# Epoch 9, training accuracy: 7398 / 8400 (88.07%); validation accuracy: 546 / 600 (91.0%)
# Epoch 10, training accuracy: 7389 / 8400 (87.96%); validation accuracy: 548 / 600 (91.33%)
# Epoch 11, training accuracy: 7409 / 8400 (88.20%); validation accuracy: 577 / 600 (96.16%)
# Epoch 12, training accuracy: 7416 / 8400 (88.28%); validation accuracy: 552 / 600 (92.0%)
# Epoch 13, training accuracy: 7382 / 8400 (87.88%); validation accuracy: 566 / 600 (94.33%)
# Epoch 14, training accuracy: 7453 / 8400 (88.72%); validation accuracy: 574 / 600 (95.66%)
# Epoch 15, training accuracy: 7434 / 8400 (88.5%); validation accuracy: 554 / 600 (92.33%)
# Epoch 16, training accuracy: 7469 / 8400 (88.91%); validation accuracy: 565 / 600 (94.16%)
# Epoch 17, training accuracy: 7452 / 8400 (88.71%); validation accuracy: 573 / 600 (95.5%)
# Epoch 18, training accuracy: 7444 / 8400 (88.61%); validation accuracy:
training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 81, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 573 / 600 (95.5%)
# Epoch 82, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 573 / 600 (95.5%)
# Epoch 83, training accuracy: 7532 / 8400 (89.66%); validation accuracy: 573 / 600 (95.5%)
# Epoch 84, training accuracy: 7528 / 8400 (89.61%); validation accuracy: 573 / 600 (95.5%)
# Epoch 85, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 572 / 600 (95.33%)
# Epoch 86, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 87, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 572 / 600 (95.33%)
# Epoch 88, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 89, training accuracy: 7532 / 8400 (89.66%); validation accuracy: 573 / 600 (95.5%)
# Epoch 90, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 91, training accuracy: 7532 / 8400 (89.66%); validation accuracy: 573 / 600 (95.5%)
# Epoch 92, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 93, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 573 / 600 (95.5%)
# Epoch 94, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 573 / 600 (95.5%)
# Epoch 95, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 96, training accuracy: 7532 / 8400 (89.66%); validation accuracy: 573 / 600 (95.5%)
# Epoch 97, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 98, training accuracy: 7527 / 8400 (89.60%); validation accuracy: 572 / 600 (95.33%)
# Epoch 99, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 100, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 573 / 600 (95.5%)
# Epoch 101, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 573 / 600 (95.5%)
# Epoch 102, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 573 / 600 (95.5%)
# Epoch 103, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 104, training accuracy: 7532 / 8400 (89.66%); validation accuracy: 573 / 600 (95.5%)
# Epoch 105, training accuracy: 7532 / 8400 (89.66%); validation accuracy: 573 / 600 (95.5%)
# Epoch 106, training accuracy: 7532 / 8400 (89.66%); validation accuracy: 573 / 600 (95.5%)
# Epoch 107, training accuracy: 7532 / 8400 (89.66%); validation accuracy: 573 / 600 (95.5%)
# Epoch 108, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 109, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 110, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 111, training accuracy: 7529 / 8400 (89.63%); validation accuracy: 573 / 600 (95.5%)
# Epoch 112, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 113, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 114, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 115, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 116, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 117, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 118, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 119, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 120, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 121, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 122, training accuracy: 7530 / 8400 (89.64%); validation accuracy: 573 / 600 (95.5%)
# Epoch 123, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 124, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 125, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 126, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 127, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 128, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 129, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 130, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 131, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 132, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 133, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 134, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 135, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 136, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 137, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 138, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 139, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 140, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 141, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 142, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 143, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 144, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 145, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 146, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 147, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 148, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 149, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 150, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 151, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 152, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 153, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 154, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 155, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 156, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 157, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 158, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 159, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 160, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 161, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 162, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 163, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 164, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 165, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 166, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 167, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 168, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 169, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 170, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 171, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 172, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 173, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 174, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 175, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 176, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 177, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 178, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 179, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 180, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 181, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 182, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 183, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 184, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 185, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 186, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 187, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 188, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 189, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 190, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 191, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 192, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 193, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 194, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 195, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 196, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 197, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 198, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)
# Epoch 199, training accuracy: 7531 / 8400 (89.65%); validation accuracy: 573 / 600 (95.5%)

# %%
# del NN_relu
NN_relu = NeuronNetwork()
NN_relu.add_layer(25, initialization='scaled_normal', input_size=training[0][0].shape[0])
NN_relu.add_layer(25, initialization='scaled_normal')

NN_relu.fit(training_data=training, epochs=200, activation_function='relu', batch_size=64,
       learning_rate = 0.01, decreasing_rate=0.95, test_data=validation, verbose=False)
# Out:
# add layer  1
# add layer  2
# did not specify the output layer, but set 'auto', automatically added output layer based on the shape of the target.
# add layer  3
# start training!
# Epoch 0, training accuracy: 6924 / 8400 (82.42%); validation accuracy: 536 / 600 (89.33%)
# Epoch 1, training accuracy: 7179 / 8400 (85.46%); validation accuracy: 579 / 600 (96.5%)
# Epoch 2, training accuracy: 7272 / 8400 (86.57%); validation accuracy: 570 / 600 (95.0%)
# Epoch 3, training accuracy: 7286 / 8400 (86.73%); validation accuracy: 581 / 600 (96.83%)
# Epoch 4, training accuracy: 7331 / 8400 (87.27%); validation accuracy: 577 / 600 (96.16%)
# Epoch 5, training accuracy: 7387 / 8400 (87.94%); validation accuracy: 585 / 600 (97.5%)
# Epoch 6, training accuracy: 7058 / 8400 (84.02%); validation accuracy: 528 / 600 (88.0%)
# Epoch 7, training accuracy: 7331 / 8400 (87.27%); validation accuracy: 547 / 600 (91.16%)
# Epoch 8, training accuracy: 7413 / 8400 (88.25%); validation accuracy: 572 / 600 (95.33%)
# Epoch 9, training accuracy: 7420 / 8400 (88.33%); validation accuracy: 571 / 600 (95.16%)
# Epoch 10, training accuracy: 7378 / 8400 (87.83%); validation accuracy: 547 / 600 (91.16%)
# Epoch 11, training accuracy: 7413 / 8400 (88.25%); validation accuracy: 567 / 600 (94.5%)
# Epoch 12, training accuracy: 7444 / 8400 (88.61%); validation accuracy:
training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 80, training accuracy: 7459 / 8400 (88.79%); validation accuracy: 568 / 600 (94.66%)
# Epoch 81, training accuracy: 7461 / 8400 (88.82%); validation accuracy: 568 / 600 (94.66%)
# Epoch 82, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 83, training accuracy: 7459 / 8400 (88.79%); validation accuracy: 568 / 600 (94.66%)
# Epoch 84, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 85, training accuracy: 7464 / 8400 (88.85%); validation accuracy: 569 / 600 (94.83%)
# Epoch 86, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 87, training accuracy: 7466 / 8400 (88.88%); validation accuracy: 569 / 600 (94.83%)
# Epoch 88, training accuracy: 7459 / 8400 (88.79%); validation accuracy: 568 / 600 (94.66%)
# Epoch 89, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 90, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 91, training accuracy: 7464 / 8400 (88.85%); validation accuracy: 569 / 600 (94.83%)
# Epoch 92, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 93, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 569 / 600 (94.83%)
# Epoch 94, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 95, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 96, training accuracy: 7461 / 8400 (88.82%); validation accuracy: 568 / 600 (94.66%)
# Epoch 97, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 98, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 99, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 100, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 101, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 102, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 103, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 104, training accuracy: 7462 / 8400 (88.83%); validation accuracy: 568 / 600 (94.66%)
# Epoch 105, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 106, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 107, training accuracy: 7464 / 8400 (88.85%); validation accuracy: 568 / 600 (94.66%)
# Epoch 108, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 109, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 110, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 111, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 112, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 113, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 114, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 115, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 116, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 117, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 118, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 119, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 120, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 121, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 122, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 123, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 124, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 125, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 126, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 127, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 128, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 129, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 130, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 131, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 132, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 133, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 134, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 135, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 136, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 137, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 138, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 139, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 140, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 141, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 142, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 143, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 144, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 145, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 146, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 147, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 148, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 149, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 150, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 151, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 152, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 153, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 154, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 155, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 156, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 157, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 158, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 159, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 160, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 161, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 162, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 163, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 164, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 165, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 166, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 167, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 168, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 169, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 170, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 171, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 172, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 173, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 174, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 175, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 176, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 177, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 178, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 179, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 180, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 181, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 182, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 183, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 184, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 185, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 186, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 187, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 188, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 189, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 190, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 191, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 192, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 193, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 194, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 195, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 196, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 197, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 198, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)
# Epoch 199, training accuracy: 7463 / 8400 (88.84%); validation accuracy: 568 / 600 (94.66%)

# %%
NeuronNetwork.draw_boundary(training, NN_sigmoid.predict, int_to_class, title='sigmoid_boundary')
# Out:
# create prediction...
# plot data points

# %%
NeuronNetwork.draw_boundary(training, NN_relu.predict, int_to_class, title='relu_boundary')
# Out:
# create prediction...
# plot data points

# %%
NeuronNetwork.draw_boundary(training, NN_leaky_relu.predict, int_to_class, title='leaky_relu_boundary')
# Out:
# create prediction...
# plot data points

# %%
def demo(models, names):
    testing = get_data(file_path='Demo')
    test_data = pca_transform(train_df, testing)
    for model, name in zip(models, names):
        predictions = [np.argmax(model.predict(test_data[i])) for i in range(len(test_data))]
        f = open(name+'_Demo.csv', 'w')
        for i in predictions:
            f.write(str(i))
        f.close()

# %%
models = [NN_sigmoid, NN_relu, NN_leaky_relu]
names = ['sigmoid', 'relu', 'leaky_relu']
demo(models, names)
